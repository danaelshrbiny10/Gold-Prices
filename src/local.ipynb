# %% [markdown]
# # Imports Section.

# %%
"""Standard library imports."""

import pandas as pd  # Pandas for data manipulation and analysis.
from sklearn.preprocessing import MinMaxScaler   # MinMaxScaler from scikit-learn for feature scaling
from sklearn.model_selection import train_test_split  # train_test_split from scikit-learn for splitting the dataset
from sklearn.linear_model import LinearRegression   # LinearRegression from scikit-learn for linear regression modeling
from sklearn.linear_model import Ridge  # Ridge regression is a linear regression model with L2 regularization
from sklearn.model_selection import cross_val_score  # cross_val_score for cross-validation
from sklearn.feature_selection import RFE  # Recursive Feature Elimination (RFE) for feature selection

# %% [markdown]
# # Read CSV

# %%
# Read the CSV file into a Pandas DataFrame.
# The read_csv function reads the data from the CSV file and stores it in a tabular format.
# You can specify various parameters like delimiter, header, and encoding based on the file's characteristics.


data = pd.read_csv("/content/data/local.csv")

# %%
# Display the first few rows of the 'data' DataFrame.
# The head() method is used to show a preview of the data, which is useful for initial exploration.
# By default, it displays the first 5 rows, but you can specify the number of rows by passing an argument.

data.head()
# Out:
#    24K - Local Price/Sell  24K - Local Price/Buy  22K - Local Price/Sell  \
# 0                  1394.0                 1401.0                  1278.0
# 1                  1398.0                 1402.0                  1281.0
# 2                  1431.0                 1435.0                  1312.0
# 3                  1446.0                 1457.0                  1325.0
# 4                  1429.0                 1440.0                  1310.0
#
#    22K - Local Price/Buy  21K - Local Price/Sell  21K - Local Price/Buy  \
# 0                 1284.0                  1220.0                 1226.0
# 1                 1285.0                  1223.0                 1227.0
# 2                 1316.0                  1252.0                 1256.0
# 3                 1336.0                  1265.0                 1275.0
# 4                 1320.0                  1250.0                 1260.0
#
#    18K - Local Price/Sell  18K - Local Price/Buy  14K - Local Price/Sell  \
# 0                  1046.0                 1051.0                   813.0
# 1                  1048.0                 1052.0                   815.0
# 2                  1073.0                 1077.0                   835.0
# 3                  1084.0                 1093.0                   843.0
# 4                  1071.0                 1080.0                   833.0
#
#    14K - Local Price/Buy  12K - Local Price/Sell  12K - Local Price/Buy
# 0                  817.0                   697.0                  701.0
# 1                  818.0                   699.0                  701.0
# 2                  837.0                   715.0                  718.0
# 3                  850.0                   723.0                  729.0
# 4                  840.0                   714.0                  720.0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['24K - Local Price/Sell'].plot(kind='hist', bins=20, title='24K - Local Price/Sell')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['24K - Local Price/Buy'].plot(kind='hist', bins=20, title='24K - Local Price/Buy')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['22K - Local Price/Sell'].plot(kind='hist', bins=20, title='22K - Local Price/Sell')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['22K - Local Price/Buy'].plot(kind='hist', bins=20, title='22K - Local Price/Buy')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='24K - Local Price/Sell', y='24K - Local Price/Buy', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='24K - Local Price/Buy', y='22K - Local Price/Sell', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='22K - Local Price/Sell', y='22K - Local Price/Buy', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7.plot(kind='scatter', x='22K - Local Price/Buy', y='21K - Local Price/Sell', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_8['24K - Local Price/Sell'].plot(kind='line', figsize=(8, 4), title='24K - Local Price/Sell')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_9['24K - Local Price/Buy'].plot(kind='line', figsize=(8, 4), title='24K - Local Price/Buy')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_10['22K - Local Price/Sell'].plot(kind='line', figsize=(8, 4), title='22K - Local Price/Sell')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_11['22K - Local Price/Buy'].plot(kind='line', figsize=(8, 4), title='22K - Local Price/Buy')
# plt.gca().spines[['top', 'right']].set_visible(False)
# WARNING: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.

# %% [markdown]
# # spliting data

# %%
# Extracting sell prices as labels
# iloc[:, [0, 2, 4, 6, 8, 10]] selects all rows (:) and columns at indices 0, 2, 4, 6, 8, 10

labels = data.iloc[:, [0, 2, 4, 6, 8, 10]]
labels.head()
# Out:
#    24K - Local Price/Sell  22K - Local Price/Sell  21K - Local Price/Sell  \
# 0                  1394.0                  1278.0                  1220.0
# 1                  1398.0                  1281.0                  1223.0
# 2                  1431.0                  1312.0                  1252.0
# 3                  1446.0                  1325.0                  1265.0
# 4                  1429.0                  1310.0                  1250.0
#
#    18K - Local Price/Sell  14K - Local Price/Sell  12K - Local Price/Sell
# 0                  1046.0                   813.0                   697.0
# 1                  1048.0                   815.0                   699.0
# 2                  1073.0                   835.0                   715.0
# 3                  1084.0                   843.0                   723.0
# 4                  1071.0                   833.0                   714.0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_12['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_13['24K - Local Price/Sell'].plot(kind='hist', bins=20, title='24K - Local Price/Sell')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_14['22K - Local Price/Sell'].plot(kind='hist', bins=20, title='22K - Local Price/Sell')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_15['21K - Local Price/Sell'].plot(kind='hist', bins=20, title='21K - Local Price/Sell')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_16.plot(kind='scatter', x='index', y='24K - Local Price/Sell', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_17.plot(kind='scatter', x='24K - Local Price/Sell', y='22K - Local Price/Sell', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_18.plot(kind='scatter', x='22K - Local Price/Sell', y='21K - Local Price/Sell', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_19.plot(kind='scatter', x='21K - Local Price/Sell', y='18K - Local Price/Sell', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['24K - Local Price/Sell']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_20.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('24K - Local Price/Sell')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['22K - Local Price/Sell']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_21.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('22K - Local Price/Sell')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['21K - Local Price/Sell']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_22.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('21K - Local Price/Sell')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['18K - Local Price/Sell']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_23.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('18K - Local Price/Sell')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_24['index'].plot(kind='line', figsize=(8, 4), title='index')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_25['24K - Local Price/Sell'].plot(kind='line', figsize=(8, 4), title='24K - Local Price/Sell')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_26['22K - Local Price/Sell'].plot(kind='line', figsize=(8, 4), title='22K - Local Price/Sell')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_27['21K - Local Price/Sell'].plot(kind='line', figsize=(8, 4), title='21K - Local Price/Sell')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
# Extracting buy prices as features
# iloc[:, [1, 3, 5, 7, 9, 11]] selects all rows (:) and columns at indices 1, 3, 5, 7, 9, 11

features = data.iloc[:, [1, 3, 5, 7, 9, 11]]
features.head()
# Out:
#    24K - Local Price/Buy  22K - Local Price/Buy  21K - Local Price/Buy  \
# 0                 1401.0                 1284.0                 1226.0
# 1                 1402.0                 1285.0                 1227.0
# 2                 1435.0                 1316.0                 1256.0
# 3                 1457.0                 1336.0                 1275.0
# 4                 1440.0                 1320.0                 1260.0
#
#    18K - Local Price/Buy  14K - Local Price/Buy  12K - Local Price/Buy
# 0                 1051.0                  817.0                  701.0
# 1                 1052.0                  818.0                  701.0
# 2                 1077.0                  837.0                  718.0
# 3                 1093.0                  850.0                  729.0
# 4                 1080.0                  840.0                  720.0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_28['24K - Local Price/Buy'].plot(kind='hist', bins=20, title='24K - Local Price/Buy')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_29['22K - Local Price/Buy'].plot(kind='hist', bins=20, title='22K - Local Price/Buy')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_30['21K - Local Price/Buy'].plot(kind='hist', bins=20, title='21K - Local Price/Buy')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_31['18K - Local Price/Buy'].plot(kind='hist', bins=20, title='18K - Local Price/Buy')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_32.plot(kind='scatter', x='24K - Local Price/Buy', y='22K - Local Price/Buy', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_33.plot(kind='scatter', x='22K - Local Price/Buy', y='21K - Local Price/Buy', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_34.plot(kind='scatter', x='21K - Local Price/Buy', y='18K - Local Price/Buy', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_35.plot(kind='scatter', x='18K - Local Price/Buy', y='14K - Local Price/Buy', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_36['24K - Local Price/Buy'].plot(kind='line', figsize=(8, 4), title='24K - Local Price/Buy')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_37['22K - Local Price/Buy'].plot(kind='line', figsize=(8, 4), title='22K - Local Price/Buy')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_38['21K - Local Price/Buy'].plot(kind='line', figsize=(8, 4), title='21K - Local Price/Buy')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_39['18K - Local Price/Buy'].plot(kind='line', figsize=(8, 4), title='18K - Local Price/Buy')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_40['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_41['24K - Local Price/Buy'].plot(kind='hist', bins=20, title='24K - Local Price/Buy')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_42['22K - Local Price/Buy'].plot(kind='hist', bins=20, title='22K - Local Price/Buy')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_43['21K - Local Price/Buy'].plot(kind='hist', bins=20, title='21K - Local Price/Buy')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_44.plot(kind='scatter', x='index', y='24K - Local Price/Buy', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_45.plot(kind='scatter', x='24K - Local Price/Buy', y='22K - Local Price/Buy', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_46.plot(kind='scatter', x='22K - Local Price/Buy', y='21K - Local Price/Buy', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_47.plot(kind='scatter', x='21K - Local Price/Buy', y='18K - Local Price/Buy', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['24K - Local Price/Buy']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_48.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('24K - Local Price/Buy')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['22K - Local Price/Buy']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_49.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('22K - Local Price/Buy')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['21K - Local Price/Buy']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_50.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('21K - Local Price/Buy')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['18K - Local Price/Buy']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_51.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('18K - Local Price/Buy')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_52['index'].plot(kind='line', figsize=(8, 4), title='index')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_53['24K - Local Price/Buy'].plot(kind='line', figsize=(8, 4), title='24K - Local Price/Buy')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_54['22K - Local Price/Buy'].plot(kind='line', figsize=(8, 4), title='22K - Local Price/Buy')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_55['21K - Local Price/Buy'].plot(kind='line', figsize=(8, 4), title='21K - Local Price/Buy')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# # preprocessing

# %%
# Creating a MinMaxScaler instance
scale = MinMaxScaler()

# Transforming the features using Min-Max scaling
# fit_transform() scales the features to a specified range (default is [0, 1])

features = scale.fit_transform(features)
features
# Out:
# array([[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00],
#        [5.74052813e-04, 6.26174076e-04, 6.56167979e-04, 7.65696784e-04,
#         9.84251969e-04, 0.00000000e+00],
#        [1.95177956e-02, 2.00375704e-02, 1.96850394e-02, 1.99081164e-02,
#         1.96850394e-02, 1.95402299e-02],
#        ...,
#        [8.75430540e-01, 8.75391359e-01, 8.75328084e-01, 8.75191424e-01,
#         8.75984252e-01, 8.75862069e-01],
#        [8.58783008e-01, 8.59110833e-01, 8.58923885e-01, 8.59111792e-01,
#         8.59251969e-01, 8.59770115e-01],
#        [8.88633754e-01, 8.88541014e-01, 8.88451444e-01, 8.88208270e-01,
#         8.88779528e-01, 8.88505747e-01]])

# %%
scale2 = MinMaxScaler()

# Transforming the labels using Min-Max scaling
# fit_transform() scales the labels to a specified range (default is [0, 1])

labels = scale2.fit_transform(labels)
labels
# Out:
# array([[0.        , 0.        , 0.        , 0.        , 0.        ,
#         0.        ],
#        [0.00236407, 0.00193424, 0.00202703, 0.00157729, 0.00202634,
#         0.00236407],
#        [0.02186761, 0.02192134, 0.02162162, 0.02129338, 0.02228977,
#         0.0212766 ],
#        ...,
#        [0.87825059, 0.87814313, 0.87837838, 0.8785489 , 0.87841945,
#         0.87825059],
#        [0.87470449, 0.87491941, 0.875     , 0.87539432, 0.87537994,
#         0.87470449],
#        [0.90543735, 0.90522244, 0.90540541, 0.90536278, 0.90577508,
#         0.90543735]])

# %%
# Splitting the dataset into training and testing sets
# features and labels are split into x_train, x_test, y_train, and y_test
# test_size=0.2 indicates that 20% of the data will be used for testing, and 80% for training
x_train, x_test, y_train, y_test = train_test_split(features, labels, test_size=0
#        [0.22273249, 0.22291797, 0.22244094, 0.22205207, 0.22244094,
#         0.22183908],
#        [0.60619977, 0.60613651, 0.60629921, 0.60643185, 0.60629921,
#         0.60689655],
#        [0.72789897, 0.72761428, 0.72769029, 0.72741194, 0.72834646,
#         0.72758621],
#        [0.6326062 , 0.63243582, 0.63254593, 0.63246554, 0.63287402,
#         0.63218391],
#        [0.02755454, 0.02755166, 0.02755906, 0.02756508, 0.02755906,
#         0.02758621],
#        [0.61136625, 0.61177207, 0.61154856, 0.61179173, 0.61220472,
#         0.61149425],
#        [0.2847302 , 0.2849092 , 0.2847769 , 0.2848392 , 0.28543307,
#         0.28505747],
#        [0.30309989, 0.30306825, 0.30314961, 0.30321593, 0.30314961,
#         0.30344828]])

# %%
y_train
# Out:
# array([[0.63179669, 0.63185042, 0.63175676, 0.63170347, 0.63221884,
#         0.63120567],
#        [0.67198582, 0.67182463, 0.6722973 , 0.67271293, 0.67274569,
#         0.67257683],
#        [0.63356974, 0.63378466, 0.63378378, 0.6340694 , 0.63424519,
#         0.63356974],
#        ...,
#        [0.88475177, 0.88459059, 0.88513514, 0.88564669, 0.88551165,
#         0.88534279],
#        [0.62825059, 0.62798195, 0.62837838, 0.6285489 , 0.62816616,
#         0.62884161],
#        [0.83747045, 0.83752418, 0.83783784, 0.83832808, 0.8378926 ,
#         0.83806147]])

# %%
y_test
# Out:
# array([[0.37825059, 0.37846551, 0.37837838, 0.3785489 , 0.37892604,
#         0.37825059],
#        [0.37174941, 0.37137331, 0.37162162, 0.3714511 , 0.37183384,
#         0.37115839],
#        [0.67553191, 0.6756931 , 0.67567568, 0.67586751, 0.67578521,
#         0.67612293],
#        [0.40543735, 0.40554481, 0.40540541, 0.40536278, 0.40526849,
#         0.40543735],
#        [0.66548463, 0.66537718, 0.66554054, 0.66561514, 0.6656535 ,
#         0.66548463],
#        [0.70921986, 0.70921986, 0.70945946, 0.70977918, 0.70921986,
#         0.70921986],
#        [0.64834515, 0.6486138 , 0.64864865, 0.64905363, 0.64842958,
#         0.64893617],
#        [0.75      , 0.74983881, 0.75      , 0.75      , 0.74974671,
#         0.74940898],
#        [0.65189125, 0.65183752, 0.65202703, 0.6522082 , 0.65248227,
#         0.65248227],
#        [0.65543735, 0.65506125, 0.65540541, 0.65536278, 0.65552178,
#         0.65484634],
#        [0.35165485, 0.3513862 , 0.35135135, 0.35094637, 0.35157042,
#         0.35106383],
#        [0.3108747 , 0.31076725, 0.31081081, 0.31072555, 0.31104357,
#         0.3108747 ],
#        [0.66489362, 0.66473243, 0.66486486, 0.6648265 , 0.66464032,
#         0.6643026 ],
#        [0.66548463, 0.66537718, 0.66554054, 0.66561514, 0.6656535 ,
#         0.66548463],
#        [0.94562648, 0.94584139, 0.94594595, 0.94637224, 0.94630193,
#         0.94562648],
#        [0.69267139, 0.69245648, 0.69256757, 0.69242902, 0.69300912,
#         0.69267139],
#        [0.42553191, 0.42553191, 0.42567568, 0.42586751, 0.42553191,
#         0.42553191],
#        [0.63179669, 0.63185042, 0.63175676, 0.63170347, 0.63221884,
#         0.63120567],
#        [0.52718676, 0.52675693, 0.52702703, 0.52681388, 0.52684904,
#        [0.35165485, 0.3513862 , 0.35135135, 0.35094637, 0.35157042,
#         0.35106383],
#        [0.63534279, 0.63507415, 0.63513514, 0.63485804, 0.63525836,
#         0.63475177],
#        [0.65898345, 0.65892972, 0.65878378, 0.65851735, 0.6585613 ,
#         0.65839243],
#        [0.32801418, 0.32753063, 0.3277027 , 0.32728707, 0.32826748,
#         0.32742317],
#        [0.6891253 , 0.68923275, 0.68918919, 0.68927445, 0.68895643,
#         0.6891253 ],
#        [0.14893617, 0.14893617, 0.14864865, 0.14826498, 0.14893617,
#         0.14893617],
#        [0.46631206, 0.46615087, 0.46621622, 0.46608833, 0.46605876,
#         0.46572104],
#        [0.75650118, 0.75628627, 0.75675676, 0.75709779, 0.75683891,
#         0.75650118],
#        [0.62174941, 0.62153449, 0.62162162, 0.6214511 , 0.62208713,
#         0.62174941],
#        [0.81737589, 0.81753707, 0.81756757, 0.81782334, 0.81762918,
#         0.8179669 ],
#        [0.21985816, 0.21985816, 0.21959459, 0.2192429 , 0.21985816,
#         0.21985816],
#        [0.61465721, 0.6144423 , 0.61486486, 0.61514196, 0.61499493,
#         0.61465721],
#        [0.73995272, 0.73952289, 0.73986486, 0.73974763, 0.73961499,
#         0.73995272],
#        [0.64834515, 0.6486138 , 0.64864865, 0.64905363, 0.64842958,
#         0.64893617],
#        [0.02836879, 0.02836879, 0.02837838, 0.02839117, 0.02836879,
#         0.02836879],
#        [0.63120567, 0.63120567, 0.63108108, 0.63091483, 0.63120567,
#         0.63120567],
#        [0.27718676, 0.27724049, 0.27702703, 0.27681388, 0.27760892,
#         0.27659574],
#        [0.31205674, 0.31205674, 0.31216216, 0.31230284, 0.31205674,
#         0.31205674]])

# %%
print(len(features))
# Out:
# 349

# %%
print(len(x_train))
# Out:
# 279

# %%
print(len(x_test))
# Out:
# 70

# %% [markdown]
# # LinearRegression

# %%
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# Evaluating the model's performance on the test set
# model.score(x_test, y_test) computes the coefficient of determination (R²)
# to assess how well the model predicts the target variable y_test based on the features x_test

model.score(x_test,y_test)
# Out:
# 0.9986909084801693

# %% [markdown]
# # Regularization with Ridge Regression

# %%
# Create a Ridge regression model with regularization strength (alpha)
ridge_model = Ridge(alpha=0.1)

# Train the model
ridge_model.fit(x_train, y_train)

# Evaluate the model
ridge_score = ridge_model.score(x_test, y_test)
print("Ridge Regression Score:", ridge_score)
# Out:
# Ridge Regression Score: 0.998671985226557

# %% [markdown]
# # Cross-Validation

# %%
# Perform cross-validation to get a more robust estimate of performance
scores = cross_val_score(LinearRegression(), features, labels, cv=5)
print("Cross-Validation Scores:", scores)
# Out:
# Cross-Validation Scores: [-1.54200437e+18  9.94783317e-01  9.93674068e-01  9.71987347e-01
#   9.93305599e-01]

# %% [markdown]
# # Feature Selection with Recursive Feature Elimination (RFE)

# %%
# Use RFE for feature selection
model = LinearRegression()
rfe = RFE(model, n_features_to_select=6)  # Adjust the number of features as needed
x_train_rfe = rfe.fit_transform(x_train, y_train)
x_test_rfe = rfe.transform(x_test)

# Train and evaluate the model with selected features
model.fit(x_train_rfe, y_train)
rfe_score = model.score(x_test_rfe, y_test)
print("RFE Score:", rfe_score)
# Out:
# RFE Score: 0.9986909084801695
